# %%
from glob import glob
import pandas as pd
import json
import os
import torch
import IPython.display as ipd

torch.set_grad_enabled(False)

from transformers import AutoTokenizer, AddedToken
from streaming import MDSWriter
from streaming.base.format.mds.encodings import Encoding, _encodings
from streaming import LocalDataset
import numpy as np
from tqdm import tqdm
from multiprocess import Pool
import itertools

def chunks(l, n):
    for i in range(0, len(l), n):
        yield (l[i: i + n], i // n)

def multiprocessing(strings, function, cores=6, returned=True):
    df_split = chunks(strings, len(strings) // cores)
    pool = Pool(cores)
    pooled = pool.map(function, df_split)
    pool.close()
    pool.join()

    if returned:
        return list(itertools.chain(*pooled))

class UInt32(Encoding):
    def encode(self, obj) -> bytes:
        return obj.tobytes()

    def decode(self, data: bytes):
        return np.frombuffer(data, np.uint32)

_encodings['uint32'] = UInt32

columns = {
    'input_ids': 'uint32',
    'position_ids': 'uint32',
    'attention_mask': 'uint32',
    'audio': 'str',
    'text': 'str'
}
hashes = 'sha1', 'xxh64'

def new_path(f):
    splitted = f.split('/')
    base_folder = splitted[0] + '_trim'
    splitted = '/'.join([base_folder] + splitted[1:])
    return splitted

def new_path_neucodec(f):
    splitted = f.split('/')
    folder = f.split('/')[0]
    folder = folder + '_neucodec'
    new_f = os.path.join(folder, '/'.join(splitted[1:]))
    new_f = new_f.replace('.mp3', '.json').replace('.wav', '.json')
    return new_f
# Out:
# /root/.venv/lib/python3.12/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]

# %%
from datasets import load_dataset

ds = load_dataset("Scicom-intl/Emilia-YODAS-Voice-Conversion")

# %%
rows = ds['train'].to_list()

# %%
f = new_path_neucodec(new_path(rows[0]['reference_audio']))

# %%
tokenizer = AutoTokenizer.from_pretrained('Qwen/Qwen3-1.7B-Base')
extra = [AddedToken('<|speech_start|>')]
for i in range(65536):
    extra.append(AddedToken(f'<|s_{i}|>'))
tokenizer.add_tokens(extra)
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# 65537

# %%
import gc

def collator(batch, batch_position_ids):
    input_ids = []
    position_ids = []
    masks = []
    for i in range(len(batch)):
        l = len(batch[i])
        input_ids.extend(batch[i])
        position_ids.extend(batch_position_ids[i])
        masks.append(l)
    
    return {
        'input_ids': np.array(input_ids).astype(np.uint32),
        'position_ids': np.array(position_ids).astype(np.uint32),
        'attention_mask': np.array(masks).astype(np.uint32),
        'audio': '',
        'text': '',
    }

def slice_and_balance(nested_list, size):
    first = []
    balance = []
    current_size = 0

    for sublist in nested_list:
        if current_size < size:
            remaining_space = size - current_size
            if len(sublist) <= remaining_space:
                first.append(sublist)
                current_size += len(sublist)
            else:
                first.append(sublist[:remaining_space])
                balance.append(sublist[remaining_space:])
                current_size = size
        else:
            balance.append(sublist)
    
    return first, balance

# %%
import time

sequence_length = 1024 * 10
def loop(files, block_size = sequence_length):
    rows, index = files
    out_root = f'emilia-yodas/tokenized-{index}'
    os.system(f'rm -rf {out_root}')
    count = 0
    temp = []
    position_ids = []
    last_block, last_position_block = None, None
    with MDSWriter(out=out_root, columns=columns, compression=None, hashes=hashes) as out:
        for row in tqdm(rows):

            try:
                with open(new_path_neucodec(new_path(row['reference_audio']))) as fopen:
                    left = json.load(fopen)
            except:
                continue
            
            try:
                with open(new_path_neucodec(new_path(row['target_audio']))) as fopen:
                    right = json.load(fopen)
            except:
                continue

            left_text = row['reference_text']
            right_text = row['target_text']

            if len(left_text.split()) > len(left):
                continue

            if len(right_text.split()) > len(right):
                continue
            
            left_token = ''.join([f'<|s_{t}|>' for t in left])
            right_token = ''.join([f'<|s_{t}|>' for t in right])
            
            left_prompt = f'<|im_start|>{left_text}<|speech_start|>{left_token}<|im_end|>'
            right_prompt = f'<|im_start|>{right_text}<|speech_start|>{right_token}<|im_end|>'

            prompt = left_prompt + right_prompt
            
            outputs = tokenizer(prompt, add_special_tokens = False)
            position = range(len(outputs['input_ids']))
            length = len(outputs['input_ids'])
            
            if count + length > block_size:
                o = collator(temp, position_ids)
                if o['input_ids'].shape[0] > 0:
                    out.write(o)
                temp = [outputs['input_ids']]
                position_ids = [position]
                count = length
                
            else:
                temp.append(outputs['input_ids'])
                position_ids.append(range(len(outputs['input_ids'])))
                count += len(outputs['input_ids'])
        
        if len(temp):
            o = collator(temp, position_ids)
            if o['input_ids'].shape[0] > 0:
                out.write(o)

# %%
multiprocessing(rows, loop, cores = 40, returned = False)

# %%
folders = sorted(glob('emilia-yodas/tokenized-*'), key = lambda x: int(x.split('-')[-1]))

# %%
# !rm -rf multipacking-emilia-yodas

# %%
with MDSWriter(out='multipacking-emilia-yodas', columns=columns, compression=None, hashes=hashes) as out:
    for f in folders:
        try:
            dataset = LocalDataset(local=f)
            for i in tqdm(range(len(dataset))):
                out.write(dataset[i])
        except Exception as e:
            print(e)
            pass
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 85024/85024 [00:17<00:00, 4762.79it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 85556/85556 [00:17<00:00, 4858.27it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 85644/85644 [00:17<00:00, 4796.64it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 85189/85189 [00:17<00:00, 4887.86it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 85452/85452 [00:17<00:00, 4845.43it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 85578/85578 [00:17<00:00, 4764.24it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 84825/84825 [00:17<00:00, 4834.83it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 84893/84893 [00:18<00:00, 4690.60it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 85415/85415 [00:18<00:00, 4735.58it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 84646/84646 [00:17<00:00, 4825.67it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 85108/85108 [00:17<00:00, 4770.43it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 85303/85303 [00:17<00:00, 4816.99it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 84901/84901 [00:17<00:00, 4917.78it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 85287/85287 [00:17<00:00, 4893.36it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 81933/81933 [00:16<00:00, 4837.31it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 78208/78208 [00:16<00:00, 4784.88it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 78210/78210 [00:16<00:00, 4742.31it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 78310/78310 [00:16<00:00, 4798.77it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 78036/78036 [00:16<00:00, 4701.41it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 78048/78048 [00:16<00:00, 4751.77it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 78186/78186 [00:16<00:00, 4725.07it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 78026/78026 [00:16<00:00, 4818.17it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 77290/77290 [00:16<00:00, 4748.82it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 47922/47922 [00:09<00:00, 4919.99it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 47965/47965 [00:09<00:00, 4838.81it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 47740/47740 [00:10<00:00, 4681.03it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 47579/47579 [00:10<00:00, 4462.00it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 47742/47742 [00:10<00:00, 4357.91it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 47923/47923 [00:10<00:00, 4684.73it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 47806/47806 [00:10<00:00, 4695.20it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 47854/47854 [00:10<00:00, 4730.10it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 47606/47606 [00:09<00:00, 4844.51it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 47548/47548 [00:09<00:00, 4795.91it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 47803/47803 [00:10<00:00, 4562.64it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 47566/47566 [00:09<00:00, 4852.22it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 47845/47845 [00:09<00:00, 4806.82it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 47530/47530 [00:09<00:00, 4870.32it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 47982/47982 [00:09<00:00, 4810.20it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 47720/47720 [00:09<00:00, 4864.94it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 79966/79966 [00:16<00:00, 4837.58it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 6132.02it/s]

# %%
dataset = LocalDataset('multipacking-emilia-yodas')
len(dataset)
# Out:
# 2743166

# %%
tokenizer.decode(dataset[0]['input_ids'])
# Out:
# '<|im_start|>而更重要的事情是今年瑞赤人影年,也就是我们陈部长的破关之年。这种破关之年,诸事不利,行事倒行逆施。虽然他本人可能没有这个心态,也没有这个想法,但是他当他去实行他的业务的时候,就是会产生这样的结果。<|speech_start|><|s_50598|><|s_52429|><|s_55786|><|s_36294|><|s_3312|><|s_52470|><|s_22196|><|s_19085|><|s_21880|><|s_10782|><|s_12345|><|s_9741|><|s_5945|><|s_6062|><|s_35192|><|s_50328|><|s_35301|><|s_52422|><|s_22093|><|s_26500|><|s_43788|><|s_45848|><|s_30220|><|s_30486|><|s_16100|><|s_7154|><|s_56213|><|s_55613|><|s_48686|><|s_15161|><|s_13385|><|s_12907|><|s_15661|><|s_29166|><|s_28333|><|s_21210|><|s_2958|><|s_1852|><|s_17229|><|s_6953|><|s_39209|><|s_18473|><|s_44379|><|s_6937|><|s_18254|><|s_39467|><|s_50987|><|s_18201|><|s_41598|><|s_9269|><|s_34219|><|s_17664|><|s_23066|><|s_55594|><|s_3189|><|s_19494|><|s_27403|><|s_1818|><|s_17166|><|s_6192|><|s_12875|><|s_9768|><|s_37254|><|s_51761|><|s_50583|><|s_40289|><|s_2529|><|s_36342|><|s_51581|><|s_42039|><|s_12838|><|s_29862|><|s_25195|><|s_49122|><|s_41938|><|s_17273|><|s_788|><|s_553|><|s_34325|><|s_33613|><|s_1813|><|s_43291|><|s_35127|><|s_2171|><|s_18738|><|s_17515|><|s_33914|><|s_65294|><|s_13901|><|s_11033|><|s_18180|><|s_33658|><|s_53281|><|s_41662|><|s_21010|><|s_55335|><|s_35114|><|s_2153|><|s_2309|><|s_18537|><|s_35111|><|s_34570|><|s_35370|><|s_12363|><|s_44852|><|s_26503|><|s_48435|><|s_50057|><|s_60196|><|s_13128|><|s_26198|><|s_37241|><|s_49784|><|s_37499|><|s_24954|><|s_25979|><|s_27518|><|s_44906|><|s_30390|><|s_48354|><|s_35830|><|s_47798|><|s_309|><|s_46713|><|s_326|><|s_29337|><|s_12618|><|s_489|><|s_24981|><|s_57846|><|s_49297|><|s_18662|><|s_35059|><|s_54002|><|s_46011|><|s_34145|><|s_13929|><|s_12868|><|s_29655|><|s_58791|><|s_55611|><|s_2170|><|s_18807|><|s_56103|><|s_20043|><|s_17509|><|s_1134|><|s_11192|><|s_8633|><|s_58808|><|s_51640|><|s_51554|><|s_6561|><|s_2273|><|s_58615|><|s_54225|><|s_59387|><|s_63411|><|s_54691|><|s_49179|><|s_23366|><|s_1193|><|s_2189|><|s_26230|><|s_51246|><|s_18487|><|s_52063|><|s_3901|><|s_17775|><|s_2416|><|s_30523|><|s_49008|><|s_46197|><|s_14644|><|s_17852|><|s_30321|><|s_20219|><|s_31459|><|s_31949|><|s_22609|><|s_23177|><|s_14102|><|s_15243|><|s_55653|><|s_56660|><|s_60462|><|s_22549|><|s_26637|><|s_42839|><|s_13644|><|s_29722|><|s_27213|><|s_26471|><|s_7166|><|s_38835|><|s_56806|><|s_19942|><|s_51367|><|s_64422|><|s_35762|><|s_18293|><|s_18612|><|s_14383|><|s_22374|><|s_31483|><|s_55654|><|s_52246|><|s_22826|><|s_9997|><|s_12814|><|s_15692|><|s_2382|><|s_48298|><|s_26533|><|s_18617|><|s_42747|><|s_56822|><|s_52450|><|s_11786|><|s_31082|><|s_2382|><|s_4140|><|s_26845|><|s_59696|><|s_55525|><|s_56482|><|s_22674|><|s_27843|><|s_22673|><|s_40182|><|s_56722|><|s_46669|><|s_63518|><|s_38952|><|s_31542|><|s_22389|><|s_17974|><|s_21808|><|s_11061|><|s_26161|><|s_13877|><|s_35120|><|s_8304|><|s_64177|><|s_58850|><|s_52577|><|s_22754|><|s_3556|><|s_36341|><|s_60342|><|s_14324|><|s_38780|><|s_1613|><|s_59421|><|s_12877|><|s_29518|><|s_31313|><|s_59078|><|s_39862|><|s_64213|><|s_65523|><|s_52726|><|s_56485|><|s_52538|><|s_52798|><|s_60250|><|s_19238|><|s_12618|><|s_1301|><|s_22343|><|s_10214|><|s_49143|><|s_29561|><|s_42359|><|s_570|><|s_29306|><|s_45620|><|s_42037|><|s_45641|><|s_40325|><|s_18066|><|s_27115|><|s_57829|><|s_55985|><|s_51281|><|s_11751|><|s_6289|><|s_40161|><|s_57606|><|s_55597|><|s_58638|><|s_51214|><|s_53513|><|s_51612|><|s_57930|><|s_56397|><|s_54281|><|s_54285|><|s_39691|><|s_55373|><|s_41545|><|s_51869|><|s_53770|><|s_51406|><|s_59718|><|s_19941|><|s_40165|><|s_54634|><|s_40735|><|s_22364|><|s_47901|><|s_30506|><|s_59690|><|s_47914|><|s_15132|><|s_9774|><|s_1596|><|s_20765|><|s_13368|><|s_9763|><|s_18089|><|s_26471|><|s_55546|><|s_56549|><|s_19685|><|s_52465|><|s_64153|><|s_60510|><|s_33897|><|s_57142|><|s_7024|><|s_46904|><|s_31601|><|s_34600|><|s_1576|><|s_8248|><|s_23089|><|s_8886|><|s_57010|><|s_51382|><|s_52213|><|s_42940|><|s_8285|><|s_43037|><|s_20557|><|s_34185|><|s_38482|><|s_27366|><|s_27302|><|s_59718|><|s_55341|><|s_36135|><|s_35685|><|s_40970|><|s_22036|><|s_2530|><|s_34290|><|s_1 ...

# %%
# !du -hs multipacking-emilia-yodas
# Out:
# 198G	multipacking-emilia-yodas

# %%
# !rm -rf emilia-yodas

# %%
# !hf upload Scicom-intl/Emilia-YODAS-multipacking-10k \
multipacking-emilia-yodas --repo-type=dataset --private
# Out:
# It seems you are trying to upload a large folder at once. This might take some time and then fail if the folder is too large. For such cases, it is recommended to upload in smaller batches or to use `HfApi().upload_large_folder(...)`/`hf upload-large-folder` instead. For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/upload#upload-a-large-folder.
# Start hashing 3160 files.
# Finished hashing 3160 files.
# Processing Files (0 / 0)      : |                  |  0.00B /  0.00B
# New Data Upload               : |                  |  0.00B /  0.00B
#
#   ...lia-yodas/shard.00002.mds:   4%|▌             | 2.59MB / 67.1MB
#
#
#   ...lia-yodas/shard.00000.mds:   4%|▌             | 2.61MB / 67.1MB
#
#   ...lia-yodas/shard.00002.mds:   4%|▌             | 2.59MB / 67.1MB
#
#
# Processing Files (0 / 2)      :   0%|              | 5.20MB /  212GB, 3.71MB/s
# New Data Upload               :   1%|▏             | 5.20MB /  469MB, 3.71MB/s
#
#
#
#   ...lia-yodas/shard.00009.mds:   4%|▌             | 2.64MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00012.mds:   4%|▌             | 2.59MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00005.mds:   4%|▌             | 2.62MB / 67.0MB
#
#   ...lia-yodas/shard.00002.mds:   4%|▌             | 2.59MB / 67.1MB
#
#
#   ...lia-yodas/shard.00000.mds:   4%|▌             | 2.61MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00009.mds:   4%|▌             | 2.64MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00012.mds:   4%|▌             | 2.59MB / 67.1MB
#
#
#
#
#
# Processing Files (0 / 5)      :   0%|              | 13.1MB /  212GB, 8.16MB/s
# New Data Upload               :   2%|▎             | 13.1MB /  604MB, 8.16MB/s
#
#
#
#
#
#
#   ...lia-yodas/shard.00003.mds:   4%|▌             | 2.59MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00007.mds:   4%|▌             | 2.68MB / 67.1MB
#
#   ...lia-yodas/shard.00002.mds:   4%|▌             | 2.59MB / 67.1MB
#
#
#   ...lia-yodas/shard.00000.mds:   4%|▌             | 2.61MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00009.mds:   4%|▌             | 2.64MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00012.mds:   4%|▌             | 2.59MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00005.mds:   4%|▌             | 2.62MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00003.mds:   4%|▌             | 2.59MB / 67.1MB
#
#
#
#
#
#
#
# Processing Files (0 / 7)      :   0%|              | 18.3MB /  212GB, 10.2MB/s
# New Data Upload               :   3%|▍             | 18.3MB /  604MB, 10.2MB/s
#
#   ...lia-yodas/shard.00002.mds:   8%|█             | 5.18MB / 67.1MB
#
#
#   ...lia-yodas/shard.00000.mds:   4%|▌             | 2.61MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00009.mds:   4%|▌             | 2.64MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00012.mds:   4%|▌             | 2.59MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00005.mds:   4%|▌             | 2.62MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00003.mds:   4%|▌             | 2.59MB / 67.1MB
#
#
#
#
#
#
#
# Processing Files (0 / 7)      :   0%|              | 20.9MB /  212GB, 10.5MB/s
# New Data Upload               :   3%|▍             | 20.9MB /  738MB, 10.5MB/s
#
#   ...lia-yodas/shard.00002.mds:  15%|██▏           | 10.4MB / 67.1MB
#
#
#   ...lia-yodas/shard.00000.mds:   4%|▌             | 2.61MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00009.mds:   8%|█             | 5.29MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00012.mds:   4%|▌             | 2.59MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00005.mds:   4%|▌             | 2.62MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00003.mds:   4%|▌             | 2.59MB / 67.1MB
#
#
#
#
#
#
#
# Processing Files (0 / 7)      :   0%|              | 28.7MB /  212GB, 13.1MB/s
# New Data Upload               :   3%|▍             | 28.7MB /  872MB, 13.1MB/s
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00016.mds:   4%|▌             | 2.69MB / 67.1MB
#
#   ...lia-yodas/shard.00002.mds:  23%|███▏          | 15.5MB / 67.1MB
#
#
#   ...lia-yodas/shard.00000.mds:   4%|▌             | 2.61MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00009.mds:   8%|█             | 5.29MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00012.mds:   4%|▌             | 2.59MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00005.mds:   4%|▌             | 2.62MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00003.mds:   4%|▌             | 2.59MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00007.mds:   8%|█             | 5.36MB / 67.1MB
#
#
#
#
#
#
#
#
# Processing Files (0 / 8)      :   0%|              | 39.3MB /  212GB, 16.4MB/s
# New Data Upload               :   4%|▌             | 39.3MB /  939MB, 16.4MB/s
#
#   ...lia-yodas/shard.00002.mds:  23%|███▏          | 15.5MB / 67.1MB
#
#
#   ...lia-yodas/shard.00000.mds:   8%|█             | 5.22MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00009.mds:  12%|█▋            | 7.93MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00012.mds:   8%|█             | 5.18MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00005.mds:   8%|█             | 5.25MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00003.mds:   4%|▌             | 2.59MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00007.mds:   8%|█             | 5.36MB / 67.1MB
#
#
#
#
#
#
#
#
# Processing Files (0 / 8)      :   0%|              | 49.7MB /  212GB, 19.1MB/s
# New Data Upload               :   5%|▋             | 49.7MB / 1.07GB, 19.1MB/s
#
#   ...lia-yodas/shard.00002.mds:  31%|████▎         | 20.7MB / 67.1MB
#
#
#   ...lia-yodas/shard.00000.mds:   8%|█             | 5.22MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00009.mds:  20%|██▊           | 13.2MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00012.mds:  12%|█▌            | 7.77MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00005.mds:  12%|█▋            | 7.87MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00003.mds:   4%|▌             | 2.59MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00007.mds:  24%|███▎          | 16.1MB / 67.1MB
#
#
#
#
#
#
#
#
# Processing Files (0 / 8)      :   0%|              | 76.1MB /  212GB, 27.2MB/s
# New Data Upload               :   7%|▉             | 76.1MB / 1.07GB, 27.2MB/s
#
#   ...lia-yodas/shard.00002.mds:  31%|████▎         | 20.7MB / 67.1MB
#
#
#   ...lia-yodas/shard.00000.mds:   8%|█             | 5.22MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00009.mds:  32%|████▍         | 21.1MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00012.mds:  19%|██▋           | 12.9MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00005.mds:  16%|██▏           | 10.5MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00003.mds:  12%|█▌            | 7.77MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00007.mds:  24%|███▎          | 16.1MB / 67.1MB
#
#
#
#
#
#
#
#
# Processing Files (0 / 8)      :   0%|              | 99.7MB /  212GB, 33.2MB/s
# New Data Upload               :   9%|█▎            | 99.7MB / 1.07GB, 33.2MB/s
#
#   ...lia-yodas/shard.00002.mds:  54%|███████▌      | 36.2MB / 67.1MB
#
#
#   ...lia-yodas/shard.00000.mds:  16%|██▏           | 10.4MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00009.mds:  32%|████▍         | 21.1MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00012.mds:  19%|██▋           | 12.9MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00005.mds:  23%|███▎          | 15.7MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00003.mds:  12%|█▌            | 7.77MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00007.mds:  36%|█████         | 24.1MB / 67.1MB
#
#
#
#
#
#
#
#
# Processing Files (0 / 8)      :   0%|              |  134MB /  212GB, 41.8MB/s
# New Data Upload               :  12%|█▋            |  134MB / 1.07GB, 41.8MB/s
#
#   ...lia-yodas/shard.00002.mds:  62%|████████▋     | 41.4MB / 67.1MB
#
#
#   ...lia-yodas/shard.00000.mds:  23%|███▎          | 15.7MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00009.mds:  32%|████▍         | 21.1MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00012.mds:  27%|███▊          | 18.1MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00005.mds:  23%|███▎          | 15.7MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00003.mds:  12%|█▌            | 7.77MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00007.mds:  36%|█████         | 24.1MB / 67.1MB
#
#
#
#
#
#
#
#
# Processing Files (0 / 8)      :   0%|              |  152MB /  212GB, 44.7MB/s
# New Data Upload               :  14%|█▉            |  152MB / 1.07GB, 44.7MB/s
#
#   ...lia-yodas/shard.00002.mds:  85%|███████████▉  | 56.9MB / 67.1MB
#
#
#   ...lia-yodas/shard.00000.mds:  23%|███▎          | 15.7MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00009.mds:  32%|████▍         | 21.1MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00012.mds:  27%|███▊          | 18.1MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00005.mds:  23%|███▎          | 15.7MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00003.mds:  15%|██▏           | 10.4MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00007.mds:  44%|██████▏       | 29.5MB / 67.1MB
#
#
#
#
#
#
#
#
# Processing Files (0 / 8)      :   0%|              |  178MB /  212GB, 49.5MB/s
# New Data Upload               :  17%|██▎           |  178MB / 1.07GB, 49.5MB/s
#
#   ...lia-yodas/shard.00002.mds:  96%|█████████████▌| 64.7MB / 67.1MB
#
#
#   ...lia-yodas/shard.00000.mds:  31%|████▎         | 20.9MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00009.mds:  43%|██████        | 29.1MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00012.mds:  27%|███▊          | 18.1MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00005.mds:  35%|████▉         | 23.6MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00003.mds:  27%|███▊          | 18.1MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00007.mds:  68%|█████████▌    | 45.6MB / 67.1MB
#
#
#
#
#
#
#
#
# Processing Files (0 / 8)      :   0%|              |  231MB /  212GB, 60.7MB/s
# New Data Upload               :  22%|███           |  231MB / 1.07GB, 60.7MB/s
#
#   ...lia-yodas/shard.00002.mds:  96%|█████████████▌| 64.7MB / 67.1MB
#
#
#   ...lia-yodas/shard.00000.mds:  31%|████▎         | 20.9MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00009.mds:  51%|███████▏      | 34.4MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00012.mds:  27%|███▊          | 18.1MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00005.mds:  35%|████▉         | 23.6MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00003.mds:  27%|███▊          | 18.1MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00007.mds:  88%|████████████▎ | 59.0MB / 67.1MB
#
#
#
#
#
#
#
#
# Processing Files (0 / 8)      :   0%|              |  255MB /  212GB, 63.7MB/s
# New Data Upload               :  24%|███▎          |  255MB / 1.07GB, 63.7MB/s
#
#   ...lia-yodas/shard.00002.mds:  96%|█████████████▌| 64.7MB / 67.1MB
#
#
#   ...lia-yodas/shard.00000.mds:  31%|████▎         | 20.9MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00009.mds:  63%|████████▊     | 42.3MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00012.mds:  39%|█████▍        | 25.9MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00005.mds:  47%|██████▌       | 31.5MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00003.mds:  27%|███▊          | 18.1MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00007.mds: 100%|█████████████▉| 67.0MB / 67.1MB
#
#
#
#
#
#
#
#
# Processing Files (0 / 8)      :   0%|              |  287MB /  212GB, 68.2MB/s
# New Data Upload               :  27%|███▋          |  287MB / 1.07GB, 68.2MB/s
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00011.mds:  29%|████          | 19.2MB / 67.1MB
#
#   ...lia-yodas/shard.00002.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#   ...lia-yodas/shard.00000.mds:  31%|████▎         | 20.9MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00009.mds:  75%|██████████▍   | 50.2MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00012.mds:  54%|███████▌      | 36.3MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00005.mds:  67%|█████████▎    | 44.6MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00003.mds:  27%|███▊          | 18.1MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00007.mds: 100%|█████████████▉| 67.0MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00016.mds:  36%|█████         | 24.2MB / 67.1MB
#
#
#
#
#
#
#
#
#
# Processing Files (1 / 9)      :   0%|              |  348MB /  212GB, 79.0MB/s
# New Data Upload               :  32%|████▌         |  348MB / 1.07GB, 79.0MB/s
#
#   ...lia-yodas/shard.00002.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#   ...lia-yodas/shard.00000.mds:  43%|█████▉        | 28.7MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00009.mds:  95%|█████████████▏| 63.4MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00012.mds:  54%|███████▌      | 36.3MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00005.mds:  78%|██████████▉   | 52.5MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00003.mds:  39%|█████▍        | 25.9MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00007.mds: 100%|█████████████▉| 67.0MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00016.mds:  36%|█████         | 24.2MB / 67.1MB
#
#
#
#
#
#
#
#
#
# Processing Files (1 / 9)      :   0%|              |  401MB /  212GB, 87.1MB/s
# New Data Upload               :  37%|█████▏        |  401MB / 1.07GB, 87.1MB/s
#
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00001.mds:  28%|███▉          | 18.7MB / 67.0MB
#
#   ...lia-yodas/shard.00002.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#   ...lia-yodas/shard.00000.mds:  54%|███████▌      | 36.5MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00009.mds:  99%|█████████████▊| 66.1MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00012.mds:  54%|███████▌      | 36.3MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00005.mds:  86%|████████████  | 57.7MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00003.mds:  39%|█████▍        | 25.9MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00007.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00016.mds:  36%|█████         | 24.2MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00011.mds:  53%|███████▍      | 35.7MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (2 / 10)     :   0%|              |  435MB /  212GB, 90.7MB/s
# New Data Upload               :  41%|█████▋        |  435MB / 1.07GB, 90.7MB/s
#
#   ...lia-yodas/shard.00002.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#   ...lia-yodas/shard.00000.mds:  54%|███████▌      | 36.5MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00009.mds:  99%|█████████████▊| 66.1MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00012.mds:  70%|█████████▋    | 46.6MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00005.mds:  98%|█████████████▋| 65.6MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00003.mds:  39%|█████▍        | 25.9MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00007.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00016.mds:  48%|██████▋       | 32.2MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00011.mds:  74%|██████████▎   | 49.4MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (2 / 10)     :   0%|              |  491MB /  212GB, 98.2MB/s
# New Data Upload               :  46%|██████▍       |  491MB / 1.07GB, 98.2MB/s
#
#   ...lia-yodas/shard.00002.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#   ...lia-yodas/shard.00000.mds:  54%|███████▌      | 36.5MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00009.mds:  99%|█████████████▊| 66.1MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00012.mds:  70%|█████████▋    | 46.6MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00005.mds:  98%|█████████████▋| 65.6MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00003.mds:  39%|█████▍        | 25.9MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00007.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00016.mds:  48%|██████▋       | 32.2MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00011.mds:  98%|█████████████▋| 65.9MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (2 / 10)     :   0%|              |  508MB /  212GB, 97.6MB/s
# New Data Upload               :  42%|█████▉        |  508MB / 1.21GB, 97.6MB/s
#
#   ...lia-yodas/shard.00002.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#   ...lia-yodas/shard.00000.mds:  62%|████████▋     | 41.7MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00009.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00012.mds:  70%|█████████▋    | 46.6MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00005.mds:  98%|█████████████▋| 65.6MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00003.mds:  50%|███████       | 33.7MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00007.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00016.mds:  48%|██████▋       | 32.2MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00011.mds:  98%|█████████████▋| 65.9MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (3 / 11)     :   0%|              |  553MB /  212GB,  102MB/s
# New Data Upload               :  46%|██████▍       |  553MB / 1.21GB,  102MB/s
#
#   ...lia-yodas/shard.00000.mds:  82%|███████████▍  | 54.8MB / 67.1MB
#
#
#   ...lia-yodas/shard.00009.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00012.mds:  93%|████████████▉ | 62.2MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00005.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#
#
#   ...lia-yodas/shard.00003.mds:  66%|█████████▏    | 44.0MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00007.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00016.mds:  48%|██████▋       | 32.2MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00011.mds:  98%|█████████████▋| 65.9MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00001.mds:  91%|████████████▊ | 61.3MB / 67.0MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (4 / 12)     :   0%|              |  625MB /  212GB,  112MB/s
# New Data Upload               :  52%|███████▏      |  625MB / 1.21GB,  112MB/s
#
#   ...lia-yodas/shard.00000.mds:  93%|█████████████ | 62.6MB / 67.1MB
#
#
#   ...lia-yodas/shard.00012.mds:  93%|████████████▉ | 62.2MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00005.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#
#   ...lia-yodas/shard.00003.mds:  77%|██████████▊   | 51.8MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00007.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00016.mds:  64%|████████▉     | 43.0MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00011.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00001.mds:  99%|█████████████▉| 66.6MB / 67.0MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00010.mds:  50%|███████       | 33.7MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (5 / 13)     :   0%|              |  699MB /  212GB,  121MB/s
# New Data Upload               :  52%|███████▎      |  699MB / 1.34GB,  121MB/s
#
#   ...lia-yodas/shard.00000.mds:  93%|█████████████ | 62.6MB / 67.1MB
#
#
#   ...lia-yodas/shard.00012.mds:  93%|████████████▉ | 62.2MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00003.mds:  77%|██████████▊   | 51.8MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00007.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00016.mds:  64%|████████▉     | 43.0MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00011.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00001.mds:  99%|█████████████▉| 66.6MB / 67.0MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00010.mds:  58%|████████▏     | 38.9MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00021.mds:  50%|███████       | 33.7MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (5 / 13)     :   0%|              |  712MB /  212GB,  119MB/s
# New Data Upload               :  53%|███████▍      |  712MB / 1.34GB,  119MB/s
#
#   ...lia-yodas/shard.00000.mds:  93%|█████████████ | 62.6MB / 67.1MB
#
#
#   ...lia-yodas/shard.00012.mds:  97%|█████████████▌| 64.7MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00003.mds:  77%|██████████▊   | 51.8MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00007.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00016.mds:  76%|██████████▋   | 51.1MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00011.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00001.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00010.mds:  70%|█████████▊    | 46.7MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00021.mds:  70%|█████████▋    | 46.7MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (6 / 14)     :   0%|              |  778MB /  212GB,  125MB/s
# New Data Upload               :  58%|████████      |  778MB / 1.34GB,  125MB/s
#
#   ...lia-yodas/shard.00000.mds:  97%|█████████████▌| 65.2MB / 67.1MB
#
#
#   ...lia-yodas/shard.00012.mds:  97%|█████████████▌| 64.7MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00003.mds:  97%|█████████████▌| 64.7MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00016.mds:  76%|██████████▋   | 51.1MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00011.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00001.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00010.mds:  93%|█████████████ | 62.3MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00021.mds:  81%|███████████▎  | 54.5MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00025.mds:  70%|█████████▋    | 46.7MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (6 / 14)     :   0%|              |  829MB /  212GB,  130MB/s
# New Data Upload               :  59%|████████▏     |  829MB / 1.41GB,  130MB/s
#
#   ...lia-yodas/shard.00000.mds:  97%|█████████████▌| 65.2MB / 67.1MB
#
#
#   ...lia-yodas/shard.00012.mds:  97%|█████████████▌| 64.7MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00003.mds:  97%|█████████████▌| 64.7MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00016.mds:  88%|████████████▎ | 59.1MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00011.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00001.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00010.mds:  97%|█████████████▌| 64.9MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00021.mds:  93%|████████████▉ | 62.3MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00025.mds:  89%|████████████▍ | 59.6MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (6 / 14)     :   0%|              |  876MB /  212GB,  133MB/s
# New Data Upload               :  62%|████████▋     |  876MB / 1.41GB,  133MB/s
#
#   ...lia-yodas/shard.00000.mds:  97%|█████████████▌| 65.2MB / 67.1MB
#
#
#   ...lia-yodas/shard.00012.mds:  97%|█████████████▌| 64.7MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00003.mds:  97%|█████████████▌| 64.7MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00016.mds:  88%|████████████▎ | 59.1MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00011.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00001.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00010.mds:  97%|█████████████▌| 64.9MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00021.mds:  97%|█████████████▌| 64.9MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00025.mds:  97%|█████████████▌| 64.8MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (6 / 14)     :   0%|              |  897MB /  212GB,  132MB/s
# New Data Upload               :  61%|████████▌     |  897MB / 1.48GB,  132MB/s
#
#   ...lia-yodas/shard.00000.mds:  97%|█████████████▌| 65.2MB / 67.1MB
#
#
#   ...lia-yodas/shard.00012.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00003.mds:  97%|█████████████▌| 64.7MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00016.mds:  96%|█████████████▍| 64.5MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00011.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00001.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00010.mds:  97%|█████████████▌| 64.9MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00021.mds:  97%|█████████████▌| 64.9MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00025.mds:  97%|█████████████▌| 64.8MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (7 / 15)     :   0%|              |  930MB /  212GB,  133MB/s
# New Data Upload               :  63%|████████▊     |  930MB / 1.48GB,  133MB/s
#
#   ...lia-yodas/shard.00000.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#   ...lia-yodas/shard.00003.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00016.mds:  96%|█████████████▍| 64.5MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00011.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00001.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00010.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00021.mds:  97%|█████████████▌| 64.9MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00025.mds:  97%|█████████████▌| 64.8MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00013.mds:  88%|████████████▎ | 58.7MB / 67.0MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (10 / 18)    :   0%|              |  996MB /  212GB,  138MB/s
# New Data Upload               :  68%|█████████▍    |  996MB / 1.48GB,  138MB/s
#
#   ...lia-yodas/shard.00016.mds:  96%|█████████████▍| 64.5MB / 67.1MB
#
#
#   ...lia-yodas/shard.00001.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#   ...lia-yodas/shard.00010.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00021.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00025.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00013.mds:  99%|█████████████▊| 66.4MB / 67.0MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00014.mds:  39%|█████▍        | 25.9MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00008.mds:  27%|███▋          | 17.9MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00019.mds:  27%|███▋          | 17.9MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (12 / 20)    :   0%|              | 1.05GB /  212GB,  142MB/s
# New Data Upload               :  68%|█████████▌    | 1.05GB / 1.54GB,  142MB/s
#
#   ...lia-yodas/shard.00016.mds:  96%|█████████████▍| 64.5MB / 67.1MB
#
#
#   ...lia-yodas/shard.00021.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00025.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00013.mds:  99%|█████████████▊| 66.4MB / 67.0MB
#
#
#
#
#
#   ...lia-yodas/shard.00014.mds:  39%|█████▍        | 25.9MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00008.mds:  27%|███▋          | 17.9MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00019.mds:  27%|███▋          | 17.9MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00031.mds:  40%|█████▌        | 26.9MB / 67.0MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00029.mds:  51%|███████▏      | 34.2MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (12 / 20)    :   1%|              | 1.08GB /  212GB,  142MB/s
# New Data Upload               :  67%|█████████▎    | 1.08GB / 1.61GB,  142MB/s
#
#   ...lia-yodas/shard.00016.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#   ...lia-yodas/shard.00021.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00025.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00013.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#
#
#   ...lia-yodas/shard.00014.mds:  50%|███████       | 33.7MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00008.mds:  27%|███▋          | 17.9MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00019.mds:  38%|█████▎        | 25.5MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00031.mds:  52%|███████▎      | 34.9MB / 67.0MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00029.mds:  71%|█████████▉    | 47.3MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (14 / 22)    :   1%|              | 1.17GB /  212GB,  150MB/s
# New Data Upload               :  65%|█████████     | 1.17GB / 1.81GB,  150MB/s
#
#   ...lia-yodas/shard.00025.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#   ...lia-yodas/shard.00013.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#   ...lia-yodas/shard.00014.mds:  58%|████████      | 38.8MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00008.mds:  57%|████████      | 38.4MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00019.mds:  68%|█████████▌    | 45.9MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00031.mds:  72%|██████████    | 48.4MB / 67.0MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00029.mds:  82%|███████████▌  | 55.2MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00020.mds:  70%|█████████▋    | 46.7MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00015.mds:  27%|███▊          | 18.2MB / 67.0MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (14 / 22)    :   1%|              | 1.25GB /  212GB,  156MB/s
# New Data Upload               :  67%|█████████▎    | 1.25GB / 1.88GB,  156MB/s
#
#   ...lia-yodas/shard.00025.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#   ...lia-yodas/shard.00013.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#   ...lia-yodas/shard.00014.mds:  58%|████████      | 38.8MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00008.mds:  57%|████████      | 38.4MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00019.mds:  68%|█████████▌    | 45.9MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00031.mds:  72%|██████████    | 48.4MB / 67.0MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00029.mds:  94%|█████████████▏| 63.1MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00020.mds:  70%|█████████▋    | 46.7MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00015.mds:  27%|███▊          | 18.2MB / 67.0MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (14 / 22)    :   1%|              | 1.27GB /  212GB,  155MB/s
# New Data Upload               :  68%|█████████▌    | 1.27GB / 1.88GB,  155MB/s
#
#   ...lia-yodas/shard.00025.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#   ...lia-yodas/shard.00013.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#   ...lia-yodas/shard.00014.mds:  69%|█████████▋    | 46.6MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00008.mds:  57%|████████      | 38.4MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00019.mds:  68%|█████████▌    | 45.9MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00031.mds:  96%|█████████████▍| 64.5MB / 67.0MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00029.mds:  98%|█████████████▋| 65.7MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00020.mds:  93%|████████████▉ | 62.2MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00015.mds:  39%|█████▍        | 26.0MB / 67.0MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (14 / 22)    :   1%|              | 1.34GB /  212GB,  159MB/s
# New Data Upload               :  69%|█████████▋    | 1.34GB / 1.94GB,  159MB/s
#
#   ...lia-yodas/shard.00025.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#   ...lia-yodas/shard.00013.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#   ...lia-yodas/shard.00014.mds:  93%|████████████▉ | 62.1MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00008.mds:  76%|██████████▋   | 51.2MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00019.mds:  76%|██████████▋   | 51.0MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00031.mds:  96%|█████████████▍| 64.5MB / 67.0MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00029.mds:  98%|█████████████▋| 65.7MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00020.mds:  97%|█████████████▌| 64.8MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00015.mds:  39%|█████▍        | 26.0MB / 67.0MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (14 / 22)    :   1%|              | 1.39GB /  212GB,  161MB/s
# New Data Upload               :  69%|█████████▋    | 1.39GB / 2.01GB,  161MB/s
#
#   ...lia-yodas/shard.00025.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#   ...lia-yodas/shard.00013.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#   ...lia-yodas/shard.00014.mds:  93%|████████████▉ | 62.1MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00008.mds:  76%|██████████▋   | 51.2MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00019.mds:  76%|██████████▋   | 51.0MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00031.mds:  96%|█████████████▍| 64.5MB / 67.0MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00029.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00020.mds:  97%|█████████████▌| 64.8MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00015.mds:  54%|███████▌      | 36.4MB / 67.0MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (15 / 23)    :   1%|              | 1.42GB /  212GB,  161MB/s
# New Data Upload               :  71%|█████████▊    | 1.42GB / 2.01GB,  161MB/s
#
#   ...lia-yodas/shard.00013.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#   ...lia-yodas/shard.00014.mds:  93%|████████████▉ | 62.1MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00008.mds:  92%|████████████▊ | 61.4MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00019.mds:  99%|█████████████▊| 66.3MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00031.mds:  96%|█████████████▍| 64.5MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00029.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00020.mds:  97%|█████████████▌| 64.8MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00015.mds:  54%|███████▌      | 36.4MB / 67.0MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00033.mds:  96%|█████████████▍| 64.5MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (15 / 23)    :   1%|              | 1.46GB /  212GB,  162MB/s
# New Data Upload               :  73%|██████████▏   | 1.46GB / 2.01GB,  162MB/s
#
#   ...lia-yodas/shard.00013.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#   ...lia-yodas/shard.00014.mds:  93%|████████████▉ | 62.1MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00008.mds:  92%|████████████▊ | 61.4MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00019.mds:  99%|█████████████▊| 66.3MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00031.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00029.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00020.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00015.mds:  54%|███████▌      | 36.4MB / 67.0MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00033.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (18 / 26)    :   1%|              | 1.52GB /  212GB,  165MB/s
# New Data Upload               :  73%|██████████▎   | 1.52GB / 2.08GB,  165MB/s
#
#   ...lia-yodas/shard.00014.mds:  96%|█████████████▌| 64.7MB / 67.1MB
#
#
#   ...lia-yodas/shard.00008.mds:  99%|█████████████▉| 66.5MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00019.mds:  99%|█████████████▊| 66.3MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00020.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00015.mds:  66%|█████████▏    | 44.2MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00033.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00032.mds:  71%|█████████▉    | 47.7MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00006.mds:  49%|██████▊       | 32.7MB / 67.0MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00030.mds:  27%|███▊          | 18.4MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (18 / 26)    :   1%|              | 1.57GB /  212GB,  167MB/s
# New Data Upload               :  75%|██████████▌   | 1.57GB / 2.08GB,  167MB/s
#
#   ...lia-yodas/shard.00014.mds:  96%|█████████████▌| 64.7MB / 67.1MB
#
#
#   ...lia-yodas/shard.00008.mds:  99%|█████████████▉| 66.5MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00019.mds:  99%|█████████████▊| 66.3MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00020.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00015.mds:  66%|█████████▏    | 44.2MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00033.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00032.mds:  91%|████████████▋ | 60.9MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00006.mds:  49%|██████▊       | 32.7MB / 67.0MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00030.mds:  51%|███████▏      | 34.2MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (18 / 26)    :   1%|              | 1.61GB /  212GB,  168MB/s
# New Data Upload               :  73%|██████████▏   | 1.61GB / 2.21GB,  168MB/s
#
#   ...lia-yodas/shard.00014.mds:  96%|█████████████▌| 64.7MB / 67.1MB
#
#
#   ...lia-yodas/shard.00008.mds:  99%|█████████████▉| 66.5MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00019.mds:  99%|█████████████▊| 66.3MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00020.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00015.mds:  85%|███████████▉  | 57.1MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00033.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00032.mds:  99%|█████████████▊| 66.2MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00006.mds:  68%|█████████▍    | 45.3MB / 67.0MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00030.mds:  63%|████████▊     | 42.1MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (18 / 26)    :   1%|              | 1.65GB /  212GB,  168MB/s
# New Data Upload               :  72%|██████████▏   | 1.65GB / 2.28GB,  168MB/s
#
#   ...lia-yodas/shard.00014.mds:  96%|█████████████▌| 64.7MB / 67.1MB
#
#
#   ...lia-yodas/shard.00008.mds:  99%|█████████████▉| 66.5MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00019.mds:  99%|█████████████▊| 66.3MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00020.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00015.mds:  85%|███████████▉  | 57.1MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00033.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00032.mds:  99%|█████████████▊| 66.2MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00006.mds:  86%|████████████  | 57.9MB / 67.0MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00030.mds:  71%|█████████▉    | 47.4MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (18 / 26)    :   1%|              | 1.68GB /  212GB,  168MB/s
# New Data Upload               :  74%|██████████▎   | 1.68GB / 2.28GB,  168MB/s
#
#   ...lia-yodas/shard.00014.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#   ...lia-yodas/shard.00008.mds:  99%|█████████████▉| 66.5MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00019.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00020.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00015.mds:  85%|███████████▉  | 57.1MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00033.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00032.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00006.mds:  98%|█████████████▋| 65.4MB / 67.0MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00030.mds:  94%|█████████████▏| 63.2MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (21 / 29)    :   1%|              | 1.77GB /  212GB,  174MB/s
# New Data Upload               :  78%|██████████▊   | 1.77GB / 2.28GB,  174MB/s
#
#   ...lia-yodas/shard.00008.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#   ...lia-yodas/shard.00015.mds:  97%|█████████████▌| 64.9MB / 67.0MB
#
#
#
#   ...lia-yodas/shard.00033.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00032.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00006.mds:  98%|█████████████▋| 65.4MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00030.mds:  98%|█████████████▋| 65.8MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00022.mds:  95%|█████████████▏| 63.4MB / 67.0MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00018.mds:  27%|███▊          | 18.1MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00017.mds:  27%|███▊          | 18.1MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (22 / 30)    :   1%|              | 1.81GB /  212GB,  177MB/s
# New Data Upload               :  79%|███████████   | 1.81GB / 2.28GB,  177MB/s
#
#   ...lia-yodas/shard.00015.mds:  97%|█████████████▌| 64.9MB / 67.0MB
#
#
#   ...lia-yodas/shard.00033.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00032.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00006.mds:  98%|█████████████▋| 65.4MB / 67.0MB
#
#
#
#
#
#   ...lia-yodas/shard.00030.mds:  98%|█████████████▋| 65.8MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00022.mds:  98%|█████████████▊| 66.0MB / 67.0MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00018.mds:  27%|███▊          | 18.1MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00017.mds:  27%|███▊          | 18.1MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00027.mds:  49%|██████▉       | 33.2MB / 67.0MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (22 / 30)    :   1%|              | 1.83GB /  212GB,  179MB/s
# New Data Upload               :  76%|██████████▌   | 1.83GB / 2.41GB,  179MB/s
#
#   ...lia-yodas/shard.00015.mds:  97%|█████████████▌| 64.9MB / 67.0MB
#
#
#   ...lia-yodas/shard.00033.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00032.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00006.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#
#
#   ...lia-yodas/shard.00030.mds:  98%|█████████████▋| 65.8MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00022.mds:  98%|█████████████▊| 66.0MB / 67.0MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00018.mds:  39%|█████▍        | 25.9MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00017.mds:  42%|█████▉        | 28.4MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00027.mds:  68%|█████████▌    | 45.9MB / 67.0MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (23 / 31)    :   1%|              | 1.88GB /  212GB,  184MB/s
# New Data Upload               :  76%|██████████▌   | 1.88GB / 2.48GB,  184MB/s
#
#   ...lia-yodas/shard.00015.mds:  97%|█████████████▌| 64.9MB / 67.0MB
#
#
#   ...lia-yodas/shard.00032.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00006.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#
#   ...lia-yodas/shard.00030.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00022.mds:  98%|█████████████▊| 66.0MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00018.mds:  50%|███████       | 33.6MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00017.mds:  42%|█████▉        | 28.4MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00027.mds:  88%|████████████▎ | 58.7MB / 67.0MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00036.mds:  39%|█████▍        | 26.1MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (24 / 32)    :   1%|▏             | 1.94GB /  212GB,  190MB/s
# New Data Upload               :  76%|██████████▋   | 1.94GB / 2.55GB,  190MB/s
#
#   ...lia-yodas/shard.00015.mds:  97%|█████████████▌| 64.9MB / 67.0MB
#
#
#   ...lia-yodas/shard.00006.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#   ...lia-yodas/shard.00030.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00022.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#
#
#   ...lia-yodas/shard.00018.mds:  50%|███████       | 33.6MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00017.mds:  58%|████████      | 38.7MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00027.mds:  99%|█████████████▊| 66.3MB / 67.0MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00036.mds:  58%|████████▏     | 39.1MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00035.mds:  71%|█████████▉    | 47.8MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (25 / 33)    :   1%|▏             | 2.00GB /  212GB,  196MB/s
# New Data Upload               :  79%|███████████   | 2.00GB / 2.55GB,  196MB/s
#
#   ...lia-yodas/shard.00015.mds:  97%|█████████████▌| 64.9MB / 67.0MB
#
#
#   ...lia-yodas/shard.00030.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00022.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#
#   ...lia-yodas/shard.00018.mds:  50%|███████       | 33.6MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00017.mds:  65%|█████████▏    | 43.9MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00027.mds:  99%|█████████████▊| 66.3MB / 67.0MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00036.mds:  58%|████████▏     | 39.1MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00035.mds:  71%|█████████▉    | 47.8MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00039.mds:  40%|█████▌        | 26.6MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (25 / 33)    :   1%|▏             | 2.02GB /  212GB,  198MB/s
# New Data Upload               :  77%|██████████▊   | 2.02GB / 2.62GB,  198MB/s
#
#   ...lia-yodas/shard.00015.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#   ...lia-yodas/shard.00030.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00022.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#
#   ...lia-yodas/shard.00018.mds:  50%|███████       | 33.6MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00017.mds:  65%|█████████▏    | 43.9MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00027.mds:  99%|█████████████▊| 66.3MB / 67.0MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00036.mds:  58%|████████▏     | 39.1MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00035.mds:  91%|████████████▋ | 61.1MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00039.mds:  52%|███████▏      | 34.6MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (26 / 34)    :   1%|▏             | 2.07GB /  212GB,  203MB/s
# New Data Upload               :  77%|██████████▊   | 2.07GB / 2.68GB,  203MB/s
#
#   ...lia-yodas/shard.00030.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#   ...lia-yodas/shard.00022.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#   ...lia-yodas/shard.00018.mds:  62%|████████▋     | 41.4MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00017.mds:  65%|█████████▏    | 43.9MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00027.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00036.mds:  58%|████████▏     | 39.1MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00035.mds:  99%|█████████████▊| 66.4MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00039.mds:  71%|█████████▉    | 47.9MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00028.mds:  69%|█████████▌    | 46.0MB / 67.0MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (27 / 35)    :   1%|▏             | 2.13GB /  212GB,  208MB/s
# New Data Upload               :  76%|██████████▌   | 2.13GB / 2.82GB,  208MB/s
#
#   ...lia-yodas/shard.00022.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#   ...lia-yodas/shard.00018.mds:  73%|██████████▎   | 49.2MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00017.mds:  65%|█████████▏    | 43.9MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00027.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#
#
# ...
#
#
#   ...lia-yodas/shard.00314.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00313.mds:  98%|█████████████▋| 65.5MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00315.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00316.mds:  96%|█████████████▍| 64.5MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00317.mds:  96%|█████████████▍| 64.6MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00318.mds:  98%|█████████████▋| 65.6MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00319.mds:  51%|███████▏      | 34.2MB / 67.0MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00320.mds:  85%|███████████▉  | 57.2MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (313 / 321)  :  10%|█▍            | 21.5GB /  212GB,  266MB/s
# New Data Upload               :  97%|█████████████▌| 21.5GB / 22.1GB,  266MB/s
#
#   ...lia-yodas/shard.00312.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#   ...lia-yodas/shard.00314.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00313.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00315.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00316.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00317.mds:  96%|█████████████▍| 64.6MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00318.mds:  98%|█████████████▋| 65.6MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00319.mds:  63%|████████▊     | 42.1MB / 67.0MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00320.mds:  93%|█████████████ | 62.7MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (316 / 323)  :  10%|█▍            | 21.5GB /  212GB,  270MB/s
# New Data Upload               :  98%|█████████████▋| 21.5GB / 22.1GB,  270MB/s
#
#   ...lia-yodas/shard.00313.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#   ...lia-yodas/shard.00315.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00316.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00317.mds:  96%|█████████████▍| 64.6MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00318.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00319.mds:  71%|█████████▉    | 47.4MB / 67.0MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00320.mds:  97%|█████████████▋| 65.4MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00321.mds:  98%|█████████████▋| 65.7MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00322.mds:  28%|███▉          | 18.9MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (317 / 325)  :  10%|█▍            | 21.6GB /  212GB,  267MB/s
# New Data Upload               :  98%|█████████████▋| 21.6GB / 22.1GB,  267MB/s
#
#   ...lia-yodas/shard.00316.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#   ...lia-yodas/shard.00317.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00318.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00319.mds:  71%|█████████▉    | 47.4MB / 67.0MB
#
#
#
#
#
#   ...lia-yodas/shard.00320.mds:  97%|█████████████▋| 65.4MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00321.mds:  98%|█████████████▋| 65.7MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00322.mds:  52%|███████▎      | 35.0MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00323.mds:  51%|███████▏      | 34.4MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00324.mds:  27%|███▊          | 18.2MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (318 / 326)  :  10%|█▍            | 21.6GB /  212GB,  266MB/s
# New Data Upload               :  98%|█████████████▋| 21.6GB / 22.1GB,  266MB/s
#
#   ...lia-yodas/shard.00317.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#   ...lia-yodas/shard.00318.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00319.mds:  94%|█████████████▏| 63.2MB / 67.0MB
#
#
#
#
#   ...lia-yodas/shard.00320.mds:  97%|█████████████▋| 65.4MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00321.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00322.mds:  72%|██████████▏   | 48.5MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00323.mds:  51%|███████▏      | 34.4MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00324.mds:  27%|███▊          | 18.2MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00325.mds:  49%|██████▉       | 33.0MB / 67.0MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (319 / 327)  :  10%|█▍            | 21.7GB /  212GB,  266MB/s
# New Data Upload               :  98%|█████████████▋| 21.7GB / 22.2GB,  266MB/s
#
#   ...lia-yodas/shard.00318.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#   ...lia-yodas/shard.00319.mds:  94%|█████████████▏| 63.2MB / 67.0MB
#
#
#
#   ...lia-yodas/shard.00320.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00321.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00322.mds:  72%|██████████▏   | 48.5MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00323.mds:  71%|█████████▉    | 47.6MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00324.mds:  58%|████████      | 38.9MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00325.mds:  68%|█████████▌    | 45.7MB / 67.0MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00326.mds:  39%|█████▍        | 26.2MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (320 / 328)  :  10%|█▍            | 21.8GB /  212GB,  266MB/s
# New Data Upload               :  98%|█████████████▋| 21.8GB / 22.2GB,  266MB/s
#
#   ...lia-yodas/shard.00319.mds:  94%|█████████████▏| 63.2MB / 67.0MB
#
#
#   ...lia-yodas/shard.00320.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00321.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00322.mds:  96%|█████████████▌| 64.7MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00323.mds:  83%|███████████▌  | 55.5MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00324.mds:  58%|████████      | 38.9MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00325.mds:  87%|████████████▏ | 58.4MB / 67.0MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00326.mds:  51%|███████       | 34.1MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00327.mds:  53%|███████▎      | 35.2MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (320 / 328)  :  10%|█▍            | 21.8GB /  212GB,  268MB/s
# New Data Upload               :  98%|█████████████▋| 21.8GB / 22.3GB,  268MB/s
#
#   ...lia-yodas/shard.00319.mds:  98%|█████████████▋| 65.8MB / 67.0MB
#
#
#   ...lia-yodas/shard.00320.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00321.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00322.mds:  96%|█████████████▌| 64.7MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00323.mds:  95%|█████████████▏| 63.4MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00324.mds:  58%|████████      | 38.9MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00325.mds:  99%|█████████████▊| 66.0MB / 67.0MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00326.mds:  70%|█████████▊    | 47.2MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00327.mds:  73%|██████████▏   | 48.8MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (320 / 328)  :  10%|█▍            | 21.9GB /  212GB,  269MB/s
# New Data Upload               :  97%|█████████████▋| 21.9GB / 22.5GB,  269MB/s
#
#   ...lia-yodas/shard.00319.mds:  98%|█████████████▋| 65.8MB / 67.0MB
#
#
#   ...lia-yodas/shard.00320.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00321.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00322.mds:  96%|█████████████▌| 64.7MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00323.mds:  98%|█████████████▊| 66.1MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00324.mds:  81%|███████████▎  | 54.5MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00325.mds:  99%|█████████████▊| 66.0MB / 67.0MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00326.mds:  70%|█████████▊    | 47.2MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00327.mds:  93%|█████████████ | 62.3MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (320 / 328)  :  10%|█▍            | 21.9GB /  212GB,  270MB/s
# New Data Upload               :  97%|█████████████▌| 21.9GB / 22.5GB,  270MB/s
#
#   ...lia-yodas/shard.00319.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#   ...lia-yodas/shard.00320.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00321.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00322.mds:  96%|█████████████▌| 64.7MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00323.mds:  98%|█████████████▊| 66.1MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00324.mds:  81%|███████████▎  | 54.5MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00325.mds:  99%|█████████████▊| 66.0MB / 67.0MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00326.mds:  94%|█████████████▏| 63.0MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00327.mds:  97%|█████████████▌| 65.1MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (321 / 329)  :  10%|█▍            | 22.0GB /  212GB,  266MB/s
# New Data Upload               :  98%|█████████████▋| 22.0GB / 22.5GB,  266MB/s
#
#   ...lia-yodas/shard.00320.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#   ...lia-yodas/shard.00321.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00322.mds:  96%|█████████████▌| 64.7MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00323.mds:  98%|█████████████▊| 66.1MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00324.mds:  97%|█████████████▌| 64.9MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00325.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00326.mds:  98%|█████████████▋| 65.6MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00327.mds:  97%|█████████████▌| 65.1MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00328.mds:  91%|████████████▋ | 60.9MB / 67.0MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (322 / 330)  :  10%|█▍            | 22.0GB /  212GB,  264MB/s
# New Data Upload               :  98%|█████████████▋| 22.0GB / 22.5GB,  264MB/s
#
#   ...lia-yodas/shard.00321.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#   ...lia-yodas/shard.00322.mds:  96%|█████████████▌| 64.7MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00323.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00324.mds:  97%|█████████████▌| 64.9MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00325.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00326.mds:  98%|█████████████▋| 65.6MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00327.mds:  97%|█████████████▌| 65.1MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00328.mds:  99%|█████████████▊| 66.2MB / 67.0MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00329.mds:  28%|███▉          | 18.9MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (323 / 331)  :  10%|█▍            | 22.1GB /  212GB,  263MB/s
# New Data Upload               :  97%|█████████████▌| 22.1GB / 22.7GB,  263MB/s
#
#   ...lia-yodas/shard.00322.mds:  96%|█████████████▌| 64.7MB / 67.1MB
#
#
#   ...lia-yodas/shard.00323.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00324.mds:  97%|█████████████▌| 64.9MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00325.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#
#
#   ...lia-yodas/shard.00326.mds:  98%|█████████████▋| 65.6MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00327.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00328.mds:  99%|█████████████▊| 66.2MB / 67.0MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00329.mds:  28%|███▉          | 18.9MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00330.mds:  71%|█████████▉    | 47.9MB / 67.0MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (324 / 332)  :  10%|█▍            | 22.1GB /  212GB,  262MB/s
# New Data Upload               :  97%|█████████████▋| 22.1GB / 22.7GB,  262MB/s
#
#   ...lia-yodas/shard.00322.mds:  96%|█████████████▌| 64.7MB / 67.1MB
#
#
#   ...lia-yodas/shard.00324.mds:  97%|█████████████▌| 64.9MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00325.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#
#   ...lia-yodas/shard.00326.mds:  98%|█████████████▋| 65.6MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00327.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00328.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00329.mds:  28%|███▉          | 18.9MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00330.mds:  71%|█████████▉    | 47.9MB / 67.0MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00333.mds:  28%|███▉          | 18.7MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (325 / 333)  :  10%|█▍            | 22.1GB /  212GB,  259MB/s
# New Data Upload               :  97%|█████████████▌| 22.1GB / 22.7GB,  259MB/s
#
#   ...lia-yodas/shard.00322.mds:  96%|█████████████▌| 64.7MB / 67.1MB
#
#
#   ...lia-yodas/shard.00324.mds:  97%|█████████████▌| 64.9MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00326.mds:  98%|█████████████▋| 65.6MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00327.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00328.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00329.mds:  56%|███████▉      | 37.8MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00330.mds:  91%|████████████▊ | 61.2MB / 67.0MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00333.mds:  52%|███████▎      | 34.8MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00334.mds:  49%|██████▉       | 33.1MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (325 / 333)  :  10%|█▍            | 22.2GB /  212GB,  259MB/s
# New Data Upload               :  98%|█████████████▋| 22.2GB / 22.7GB,  259MB/s
#
#   ...lia-yodas/shard.00322.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#   ...lia-yodas/shard.00324.mds:  97%|█████████████▌| 64.9MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00326.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#   ...lia-yodas/shard.00327.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00328.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00329.mds:  56%|███████▉      | 37.8MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00330.mds:  99%|█████████████▉| 66.5MB / 67.0MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00333.mds:  64%|████████▉     | 42.8MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00334.mds:  68%|█████████▌    | 45.8MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (327 / 335)  :  11%|█▍            | 22.3GB /  212GB,  264MB/s
# New Data Upload               :  98%|█████████████▋| 22.3GB / 22.8GB,  264MB/s
#
#   ...lia-yodas/shard.00324.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#   ...lia-yodas/shard.00327.mds: 100%|██████████████| 67.1MB / 67.1MB
#
#
#
#   ...lia-yodas/shard.00328.mds: 100%|██████████████| 67.0MB / 67.0MB
#
#
#
#
#   ...lia-yodas/shard.00329.mds:  56%|███████▉      | 37.8MB / 67.1MB
#
#
#
#
#
#   ...lia-yodas/shard.00330.mds:  99%|█████████████▉| 66.5MB / 67.0MB
#
#
#
#
#
#
#   ...lia-yodas/shard.00333.mds:  72%|██████████    | 48.2MB / 67.1MB
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00334.mds:  87%|████████████▏ | 58.5MB / 67.1MB
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00335.mds:  52%|███████▏      | 34.6MB / 67.1MB
#
#
#
#
#
#
#
#
#
#   ...lia-yodas/shard.00332.mds:  39%|█████▌        | 26.4MB / 67.1MB
#
#
#
#
#
#
#
#
#
#
# Processing Files (328 / 336)  :  11%|█▍            | 22.3GB /  212GB,  265MB/s
# New Data Upload               :  98%|█████████████▋| 22.3GB / 22.9GB,  265MB/s
